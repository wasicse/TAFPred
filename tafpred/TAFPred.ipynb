# %%
#!/usr/bin/env python
# coding: utf-8
# Author : Md Wasi Ul Kabir  
# In[1]:


import pandas as pd
import numpy as np
import subprocess
import os
import shutil, errno
# from pathlib import Path
from pathlib2 import Path
# Out:
# Using cache found in /home/mkabir3/.cache/torch/hub/facebookresearch_esm_main

# %%
#Run PSSM
print("######### PSSM Running ##########\n")
os.chdir(homed)
os.chdir("./Tools/"+server+"/PSSM/")


file1 = open("./Dataset_Name.txt", "w")
file1.write(Dataset_Name)
file1.close()


command="./runPSSM"
process = subprocess.Popen([command], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
out, err = process.communicate()
print(out)

os.chdir(homed)
# bashCommand="cp -r ../Dataset/"+Dataset_Name+"/PSSM/* ./Tools/"+server+"/PSSM/"
# Dataset = subprocess.check_output(["bash","-c", bashCommand])
# print(Dataset)


print("\n######### PSSM END ##########\n")

# %%
# #Run PSSMParse
if "PSSMParse" in RunList:
	
	print("######### PSSMParse Running ##########\n")
	os.chdir(homed)
	Path("../Dataset/"+Dataset_Name+"/PSSM_Parse/").mkdir(exist_ok=True)

	os.chdir("./Tools/"+server+"/PSSM/")

	file1 = open("./Dataset_Name.txt", "w")
	file1.write(Dataset_Name)
	file1.close()


	command="Parse_PSSM.py"
	process = subprocess.Popen(["python",command], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
	out, err = process.communicate()
	print(out)
	print("\n######### PSSMParse END ##########\n")

# In[9]:

# %%
# #Run Running CNCC
if "CNCC" in RunList:
	
	print("######### CNCC Running ##########\n")
	os.chdir(homed)
	Path("../Dataset/"+Dataset_Name+"/CNCC/").mkdir(exist_ok=True)

	os.chdir("./Tools/"+server+"/CNCC/")

	file1 = open("./Dataset_Name.txt", "w")
	file1.write(Dataset_Name)
	file1.close()


	command="CNCC_Gen.py"
	process = subprocess.Popen(["python3",command], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
	out, err = process.communicate()
	print(out)
	print(err)
	print("\n######### CNCC END ##########\n")

# In[98]:

# %%
# #Run Running Dispredict
if "Dispredict" in RunList:
	
	print("######### Dispredict Running ##########\n")
	os.chdir(homed)
	Path("../Dataset/"+Dataset_Name+"/DisPredict/").mkdir(exist_ok=True)
	Path("../Dataset/"+Dataset_Name+"/DisPredict/Features").mkdir(exist_ok=True)
	Path("../Dataset/"+Dataset_Name+"/DisPredict/prediction").mkdir(exist_ok=True)

	bashCommand="cp -r  ../Dataset/"+Dataset_Name+"/PSSM/* ./Tools/"+server+"/DisPredict_v2.0/Software/PSSM/"
	Dataset = subprocess.check_output(["bash","-c", bashCommand])
	print(Dataset)

	bashCommand="cp -r  ../Dataset/"+Dataset_Name+"/FASTA ./Tools/"+server+"/DisPredict_v2.0/Software/Input/"
	Dataset = subprocess.check_output(["bash","-c", bashCommand])
	print(Dataset)

	bashCommand="cp -r  ../Dataset/"+Dataset_Name+"/id_list.txt ./Tools/"+server+"/DisPredict_v2.0/Software/Input/"
	Dataset = subprocess.check_output(["bash","-c", bashCommand])
	print(Dataset)
	
	os.chdir("./Tools/"+server+"/DisPredict_v2.0/Software/Scripts")
	command="./run_DisPredict_v2.0"
	process = subprocess.Popen([command], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
	out, err = process.communicate()
	print(out)
	print(err)

	copyFeatures()
	print("\n######### Dispredict END ##########\n")

# In[14]:

# %%
# #Run Running OPAL
if "OPAL" in RunList:
	
	Path("../Dataset/"+Dataset_Name+"/OPAL/").mkdir(exist_ok=True)
	os.chdir(homed)
	print("######### OPAL Running ##########\n")
	bashCommand="cp -r ../Dataset/"+Dataset_Name+"/PSSM/* ./Tools/"+server+"/OPAL/inputPssm/"
	Dataset = subprocess.check_output(["bash","-c", bashCommand])
	print(Dataset)

	bashCommand="cp -r ../Dataset/"+Dataset_Name+"/FASTA/* ./Tools/"+server+"/OPAL/inputFasta/"
	Dataset = subprocess.check_output(["bash","-c", bashCommand])
	print(Dataset)

	bashCommand="cp -r ../Dataset/"+Dataset_Name+"/id_list.txt ./Tools/"+server+"/OPAL/id_list.txt"
	Dataset = subprocess.check_output(["bash","-c", bashCommand])
	print(Dataset)
      
	
	os.chdir("./Tools/"+server+"/OPAL/")
	command="./runOPAL"
	process = subprocess.Popen([command], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
	out, err = process.communicate()
	print(out)
	print(err)

	copyFeatures()
	print("\n######### OPAL END ##########\n")

# In[7]:

# %%
# #Run Running Spider
if "Spider" in RunList:
	print("######### Spider Running ##########\n")



	os.chdir(homed)
	Path("../Dataset/"+Dataset_Name+"/Spider/").mkdir(exist_ok=True)

	bashCommand="cp -r ../Dataset/"+Dataset_Name+"/FASTA/* ./Tools/"+server+"/SPIDER3-Single_np/example_data/seq/"
	Dataset = subprocess.check_output(["bash","-c", bashCommand])
	print(Dataset)


	file1=open("./Tools/"+server+"/SPIDER3-Single_np/file_list","w")

	for line in open("../Dataset/"+Dataset_Name+"/id_list.txt"):
	    print(line)
	    print(line.strip()+" ./example_data/seq/"+line.strip()+".fasta")
	    file1.write(line.strip()+" ./example_data/seq/"+line.strip()+".fasta\n")
	file1.close()    

	os.chdir("./Tools/"+server+"/SPIDER3-Single_np/")
	command="./impute_script_np.sh"
	process = subprocess.Popen([command], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
	out, err = process.communicate()
	print(out)
	print(err)




	print("\n######### Spider END ##########\n")

# In[8]:

# %%
# #Run Running SpotDisorder
if "SpotDisorder" in RunList:
	print("######### SpotDisorder Running ##########\n")
	
	os.chdir(homed)
	Path("../Dataset/"+Dataset_Name+"/SpotDisorder/").mkdir(exist_ok=True)
	Path("../Dataset/"+Dataset_Name+"/SpotDisorderProba/").mkdir(exist_ok=True)

	bashCommand="cp -r ../Dataset/"+Dataset_Name+"/FASTA/* ./Tools/"+server+"/SPOT_Dis_Hoque/inputs/"
	Dataset = subprocess.check_output(["bash","-c", bashCommand])
	print(Dataset)

	bashCommand="cp -r ../Dataset/"+Dataset_Name+"/id_list.txt  ./Tools/"+server+"/SPOT_Dis_Hoque/protlist.txt"
	print(bashCommand)
	Dataset = subprocess.check_output(["bash","-c", bashCommand])
	print(Dataset)

	os.chdir("./Tools/"+server+"/SPOT_Dis_Hoque")
	command="./run_spotdis3.sh"
	process = subprocess.Popen([command], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
	out, err = process.communicate()
	print(out)
	print(err)


	print("\n######### SpotDisorder END ##########\n")
